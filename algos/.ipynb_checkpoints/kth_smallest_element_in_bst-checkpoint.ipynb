# %% [markdown]
# https://leetcode.com/problems/kth-smallest-element-in-a-bst/description/?envType=list&envId=xi4ci4ig (ref)

# %% [markdown]
# ```python
# Given the root of a binary search tree, and an integer k, return the kth smallest value (1-indexed) of all the values of the nodes in the tree.
#
#
#
# Example 1:
#
#
# Input: root = [3,1,4,null,2], k = 1
# Output: 1
# Example 2:
#
#
# Input: root = [5,3,6,2,4,null,null,1], k = 3
# Output: 3
#
#
# Constraints:
#
# The number of nodes in the tree is n.
# 1 <= k <= n <= 104
# 0 <= Node.val <= 104
#
#
# Follow up: If the BST is modified often (i.e., we can do insert and delete operations) and you need to find the kth smallest frequently, how would you optimize?
#
# ```

# %% [markdown]
# ![Screenshot%202024-02-05%20at%209.34.05%20AM.png](attachment:Screenshot%202024-02-05%20at%209.34.05%20AM.png)

# %%
# n: n
# s: n
# 38ms
# dfs

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def __init__(self):
        self.k_small = 0
        self.min_val = None

    def kthSmallest(self, root, k: int) -> int:
        if not root:
            return None

        def find_small_ele(root):
            if not root:
                return None
            
            if self.k_small == k:
                return None
            
            find_small_ele(root.left)

            if self.k_small == k:
                return None

            self.k_small += 1
            self.min_val = root.val

            find_small_ele(root.right)
        
        find_small_ele(root)
        
        return self.min_val
