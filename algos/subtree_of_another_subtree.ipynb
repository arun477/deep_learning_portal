# %% [markdown]
# https://leetcode.com/problems/subtree-of-another-tree/description/?envType=list&envId=xi4ci4ig (ref)

# %% [markdown]
# ```python
#
# Given the roots of two binary trees root and subRoot, return true if there is a subtree of root with the same structure and node values of subRoot and false otherwise.
#
# A subtree of a binary tree tree is a tree that consists of a node in tree and all of this node's descendants. The tree tree could also be considered as a subtree of itself.
#
#
#
# Example 1:
#
#
# Input: root = [3,4,5,1,2], subRoot = [4,1,2]
# Output: true
# Example 2:
#
#
# Input: root = [3,4,5,1,2,null,null,null,null,0], subRoot = [4,1,2]
# Output: false
#
#
# Constraints:
#
# The number of nodes in the root tree is in the range [1, 2000].
# The number of nodes in the subRoot tree is in the range [1, 1000].
# -104 <= root.val <= 104
# -104 <= subRoot.val <= 104
# ```

# %% [markdown]
# ![Screenshot%202024-02-12%20at%201.33.38%20PM.png](attachment:Screenshot%202024-02-12%20at%201.33.38%20PM.png)

# %%
# t: n*min(m*n) : n=len(root), m=len(subRoot)
# s: n
# 80s
# dfs

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def isSubtree(self, root, subRoot):
        def is_same(node1, node2):
            if not node1 and not node2:
                return True
            
            if not node1 or not node2:
                return False
            
            return (node1.val == node2.val) and is_same(node1.left, node2.left) and is_same(node1.right, node2.right)

        def dfs(node):
            if is_same(node, subRoot):
                return True
            
            if not node:
                return False
            
            return dfs(node.left) or dfs(node.right)
        
        return dfs(root)
