# %% [markdown]
# https://arxiv.org/pdf/1312.6114.pdf (vae paper)<br/>
# https://docs.google.com/presentation/d/1FkkhH86URDzAzjNPdCvupV6kqoBNNarVQQgB6ppZlx4/edit#slide=id.g26890724310_0_7 (latent variable models lecture notes) <br/>

# %%
# !pip install datasets
# !pip install wandb
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#      |████████████████████████████████| 253 kB 1.4 MB/s eta 0:00:01
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: joblib>=0.14 in /Applications/anaconda3/lib/python3.9/site-packages (from librosa) (1.1.0)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-macosx_10_9_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 13.5 MB/s eta 0:00:01
# Requirement already satisfied: decorator>=4.3.0 in /Applications/anaconda3/lib/python3.9/site-packages (from librosa) (5.1.0)
# Requirement already satisfied: numba>=0.51.0 in /Applications/anaconda3/lib/python3.9/site-packages (from librosa) (0.54.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Applications/anaconda3/lib/python3.9/site-packages (from librosa) (0.24.2)
# Requirement already satisfied: msgpack>=1.0 in /Applications/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Applications/anaconda3/lib/python3.9/site-packages (from librosa) (4.8.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Applications/anaconda3/lib/python3.9/site-packages (from librosa) (1.22.4)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: scipy>=1.2.0 in /Applications/anaconda3/lib/python3.9/site-packages (from librosa) (1.12.0)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.7-cp39-cp39-macosx_10_9_x86_64.whl (413 kB)
#      |████████████████████████████████| 413 kB 50.4 MB/s eta 0:00:01
# Collecting pooch>=1.0
#   Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 10.9 MB/s eta 0:00:01
# Collecting numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3
#   Downloading numpy-1.20.3-cp39-cp39-macosx_10_9_x86_64.whl (16.1 MB)
#      |████████████████████████████████| 16.1 MB 399 kB/s eta 0:00:01

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms.functional as TF
from torch.utils.data import default_collate, DataLoader
from datasets import load_dataset
import matplotlib.pyplot as plt
import wandb
import numpy as np
import librosa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/8k/07c2mpg56x7c31_26k0qj2y00000gn/T/ipykernel_22062/3407905504.py in <module>
#       8 import wandb
#       9 import numpy as np
# ---> 10 import librosa
#
# ModuleNotFoundError: No module named 'librosa'

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: carlfeynman. Use `wandb login --relogin` to force relogin

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('device', device)
# Out:
# device cpu

# %%
dataset = load_dataset('lewtun/music_genres_small')
# Out:
# Downloading readme:   0%|          | 0.00/487 [00:00<?, ?B/s]
# Downloading and preparing dataset None/None to /Users/arun/.cache/huggingface/datasets/lewtun___parquet/lewtun--music_genres_small-2686d03f87ff3ace/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/391M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Dataset parquet downloaded and prepared to /Users/arun/.cache/huggingface/datasets/lewtun___parquet/lewtun--music_genres_small-2686d03f87ff3ace/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'song_id', 'genre_id', 'genre'],
#         num_rows: 1000
#     })
# })

# %%
dataset['train'][0]['audio']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/features/audio.py in decode_example(self, value, token_per_repo_id)
#     154         try:
# --> 155             import librosa
#     156             import soundfile as sf
#
# ModuleNotFoundError: No module named 'librosa'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# /var/folders/8k/07c2mpg56x7c31_26k0qj2y00000gn/T/ipykernel_22062/627145566.py in <module>
# ----> 1 dataset['train'][0]['audio']
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/arrow_dataset.py in __getitem__(self, key)
#    2707     def __getitem__(self, key):  # noqa: F811
#    2708         """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2709         return self._getitem(key)
#    2710
#    2711     def __getitems__(self, keys: List) -> List:
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/arrow_dataset.py in _getitem(self, key, **kwargs)
#    2692         formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    2693         pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 2694         formatted_output = format_table(
#    2695             pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2696         )
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/formatting/formatting.py in format_table(table, key, formatter, format_columns, output_all_columns)
#     632     python_formatter = PythonFormatter(features=None)
#     633     if format_columns is None:
# --> 634         return formatter(pa_table, query_type=query_type)
#     635     elif query_type == "column":
#     636         if key in format_columns:
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/formatting/formatting.py in __call__(self, pa_table, query_type)
#     404     def __call__(self, pa_table: pa.Table, query_type: str) -> Union[RowFormat, ColumnFormat, BatchFormat]:
#     405         if query_type == "row":
# --> 406             return self.format_row(pa_table)
#     407         elif query_type == "column":
#     408             return self.format_column(pa_table)
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/formatting/formatting.py in format_row(self, pa_table)
#     440             return LazyRow(pa_table, self)
#     441         row = self.python_arrow_extractor().extract_row(pa_table)
# --> 442         row = self.python_features_decoder.decode_row(row)
#     443         return row
#     444
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/formatting/formatting.py in decode_row(self, row)
#     223
#     224     def decode_row(self, row: dict) -> dict:
# --> 225         return self.features.decode_example(row) if self.features else row
#     226
#     227     def decode_column(self, column: list, column_name: str) -> list:
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/features/features.py in decode_example(self, example, token_per_repo_id)
#    1862         """
#    1863
# -> 1864         return {
#    1865             column_name: decode_nested_example(feature, value, token_per_repo_id=token_per_repo_id)
#    1866             if self._column_requires_decoding[column_name]
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/features/features.py in <dictcomp>(.0)
#    1863
#    1864         return {
# -> 1865             column_name: decode_nested_example(feature, value, token_per_repo_id=token_per_repo_id)
#    1866             if self._column_requires_decoding[column_name]
#    1867             else value
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/features/features.py in decode_nested_example(schema, obj, token_per_repo_id)
#    1306         # we pass the token to read and decode files from private repositories in streaming mode
#    1307         if obj is not None and schema.decode:
# -> 1308             return schema.decode_example(obj, token_per_repo_id=token_per_repo_id)
#    1309     return obj
#    1310
#
# /Applications/anaconda3/lib/python3.9/site-packages/datasets/features/audio.py in decode_example(self, value, token_per_repo_id)
#     156             import soundfile as sf
#     157         except ImportError as err:
# --> 158             raise ImportError("To support decoding audio files, please install 'librosa' and 'soundfile'.") from err
#     159
#     160         audio_format = xsplitext(path)[1][1:].lower() if path is not None else None
#
# ImportError: To support decoding audio files, please install 'librosa' and 'soundfile'.

# %%
def transform_data(b):
    b['image'] = [TF.to_tensor(o) for o in  b['image']]
    return  b

def collate_dict(b):
    c = default_collate(b)
    return (c['image'].to(device), c['label'])

# %%
batch_size = 100

# %%
train_ds = dataset['train'].with_transform(transform_data)
valid_ds = dataset['test'].with_transform(transform_data)

# %%
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, collate_fn=collate_dict)
valid_dl = DataLoader(valid_ds, batch_size=batch_size*2, shuffle=False, collate_fn=collate_dict)

# %%
xb,yb = next(iter(train_dl))
xb.shape,yb.shape

# %%
plt.figure(figsize=(1, 1))
plt.imshow(xb[10][0].detach().cpu());
plt.axis('off');
print(yb[10])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class VariationalAutoEncoder(nn.Module):
    def __init__(self, latent_dim=50, beta=1):
        super().__init__()
        self.latent_dim = latent_dim
        self.beta = beta

        self.stride = 2
        self.kernel_size = 3
        self.padding = self.kernel_size//2

        self.enc = nn.Sequential(*[
            nn.Conv2d(1, 8, kernel_size=self.kernel_size, padding=self.padding, stride=self.stride),
            nn.BatchNorm2d(8),
            nn.ReLU(),
            nn.Conv2d(8, 16, kernel_size=self.kernel_size, padding=self.padding, stride=self.stride),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=self.kernel_size, padding=self.padding, stride=self.stride),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=self.kernel_size, padding=self.padding, stride=self.stride),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=self.kernel_size, padding=self.padding, stride=self.stride),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(64, self.latent_dim)
        ])

        self.mu_layer = nn.Linear(self.latent_dim, self.latent_dim)
        self.log_var_layer = nn.Linear(self.latent_dim, self.latent_dim)

        self.dec = nn.Sequential(*[
            nn.Linear(self.latent_dim, 64*2*2),
            nn.ReLU(),
            nn.Unflatten(1, (64,2,2)),
            nn.ConvTranspose2d(64, 32, kernel_size=self.kernel_size,
                               padding=self.padding, stride=self.stride, output_padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=self.kernel_size,
                               padding=self.padding, stride=self.stride, output_padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.ConvTranspose2d(16, 8, kernel_size=self.kernel_size,
                               padding=self.padding, stride=self.stride, output_padding=1),
            nn.BatchNorm2d(8),

            nn.ReLU(),
            nn.ConvTranspose2d(8, 1, kernel_size=self.kernel_size,
                               padding=self.padding, stride=2, output_padding=0),
            nn.BatchNorm2d(1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(961, 28*28),
            nn.Unflatten(1, (1,28,28)),
            nn.Sigmoid()
        ])

    def reparameterize(self, mu, log_var):
      std = torch.exp(0.5*log_var)
      eps = torch.randn_like(std)
      return mu + eps*std

    def loss(self, xb, out, mu, log_var):
      self.rec_loss = F.mse_loss(xb, out, reduction='mean')
      self.kl_loss = -0.5*torch.sum(1 + log_var - mu.pow(2) - log_var.exp(), dim=1).mean(dim=0)
      return self.rec_loss + self.beta*self.kl_loss

    def forward(self, x):
        latent = self.enc(x)

        mu = self.mu_layer(latent)
        log_var = self.log_var_layer(latent)

        z = self.reparameterize(mu, log_var)
        out = self.dec(z)

        return out, mu, log_var

# %%
model = VariationalAutoEncoder().to(device)
model

# %%
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
total_params = f"{total_params / 1_000_000:.2f}M"
print(f"total number of parameters: {total_params}")

# %%
out,mu,log_var = model(xb)
out.shape,mu.shape,log_var.shape

# %%
epochs = 20
lr = 6e-3
model = VariationalAutoEncoder().to(device)
opt = torch.optim.AdamW(model.parameters(), lr=lr)

wandb.init(
    project="variational_autoencoder",
    config={
      "batch_size": batch_size,
      "learning_rate": lr,
      "architecture": "CNN",
      "dataset": "MNIST",
      "epochs": epochs,
      "total_params": total_params,
      "model":model
    }
)

for epoch in range(epochs):
    for xb,yb in train_dl:
        out,mu,log_var = model(xb)
        loss = model.loss(xb, out, mu, log_var)
        loss.backward()
        opt.step()
        opt.zero_grad()

        with torch.no_grad():
          sample_mu = torch.zeros((5, model.latent_dim))
          sample_log_var = torch.ones((5, model.latent_dim))
          samples = model.reparameterize(sample_mu, sample_log_var)
          samples_out = model.dec(samples)

          wandb.log({"loss": round(loss.item(), 4),
                     "reconstruct_loss": round(model.rec_loss.item(), 4),
                     "kl_loss": round(model.kl_loss.item(), 4)})
          orginial_img = [wandb.Image(o, caption="original") for o in xb.detach().cpu()[:5]]
          reconstructed_img = [wandb.Image(o, caption="reconstructed_img") for o in out.detach().cpu()[:5]]
          generated_sample = [wandb.Image(o, caption="generated_sample") for o in samples_out.detach().cpu()[:5]]
          wandb.log({"original": orginial_img, "reconstructed_img": reconstructed_img, 'generated_sample':generated_sample})

    print(f"loss {loss.item():.4f}")

wandb.finish()

# %%
# wandb.finish()

# %%
plot_sz = 10
_,axs = plt.subplots(1, plot_sz, figsize=(15, 15))
for im,ax in zip(xb,axs.flat):
  ax.imshow(im.permute(1,2,0).detach().cpu());
  ax.axis('off')
  ax.set_title('original', fontsize=10)

# %%
_,axs = plt.subplots(1, plot_sz, figsize=(15, 15))
for im,ax in zip(out,axs.flat):
  ax.imshow(im.permute(1,2,0).detach().cpu());
  ax.axis('off')
  ax.set_title('reconstructed', fontsize=9)

# %%
_,axs = plt.subplots(1, 5, figsize=(8, 8))
for im,ax in zip(samples_out,axs.flat):
  ax.imshow(im.permute(1,2,0).detach().cpu());
  ax.axis('off')
  ax.set_title('generated', fontsize=9)
