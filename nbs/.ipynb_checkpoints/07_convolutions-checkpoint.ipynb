# %%
#|default_exp conv

# %%
#|export
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms.functional as TF
import matplotlib.pyplot as plt
from functools import partial
from datasets import load_dataset
from torch.utils.data import DataLoader, default_collate
import numpy as np
import pickle, gzip
from pathlib import Path
import matplotlib as mpl
import pandas as pd
from practice_deep_learning.training import *
from typing import Mapping

# %%
mpl.rcParams['image.cmap'] = 'gray'
# %matplotlib inline

# %%
with gzip.open('../data/mnist.pkl.gz', 'r') as f:
    ((x_train, y_train), (x_valid, y_valid), _) = pickle.load(f, encoding='latin')
(x_train, y_train, x_valid, y_valid) = map(torch.tensor, (x_train, y_train, x_valid, y_valid))
x_train.shape, y_train.shape, x_valid.shape, y_valid.shape
# Out:
# (torch.Size([50000, 784]),
#  torch.Size([50000]),
#  torch.Size([10000, 784]),
#  torch.Size([10000]))

# %%
x_imgs = x_train.view(-1, 28, 28)
xv_imgs = x_valid.view(-1, 28, 28)
im3 = x_imgs[7]
plt.imshow(im3);

# %%
top_edges = torch.tensor([
    [-1, -1, -1],
    [0, 0, 0],
    [1, 1, 1.],
])
plt.imshow(top_edges);

# %%
df = pd.DataFrame(im3.tolist())
df.style.format(precision=1).set_properties(**{'font-size':'2-pt'}).background_gradient('Greys')
# Out:
# <style type="text/css">
# ...

# %%
(im3[3:6, 14:17]*top_edges).sum()
# Out:
# tensor(2.9727)

# %%
def apply_kernel(row, col, kernel):
    return (im3[row-1:row+2, col-1:col+2]*kernel).sum()

# %%
apply_kernel(4, 15, top_edges)
# Out:
# tensor(2.9727)

# %%
print([(i, j) for j in range(5) for i in range(5)])
# Out:
# [(0, 0), (1, 0), (2, 0), (3, 0), (4, 0), (0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (0, 2), (1, 2), (2, 2), (3, 2), (4, 2), (0, 3), (1, 3), (2, 3), (3, 3), (4, 3), (0, 4), (1, 4), (2, 4), (3, 4), (4, 4)]

# %%
rng = range(1, 27)
top_edge3 = [[apply_kernel(row, col, top_edges) for col in rng] for row in rng]
plt.imshow(top_edge3);

# %%
df = pd.DataFrame(torch.tensor(top_edge3).tolist())
df.style.format(precision=1).set_properties(**{'font-size':'2-pt'}).background_gradient('Greys')
# Out:
# <style type="text/css">
# ...

# %%
left_edge = torch.tensor([
    [-1, 0, 1],
    [-1, 0, 1],
    [-1, 0, 1.],
])

# %%
left_edge3 =  [[apply_kernel(row, col, left_edge) for col in rng] for row in rng]
plt.imshow(left_edge3);

# %% [markdown]
# #### pytorch convolutions

# %%
inp = im3[None,None,:,:]
inp_unf = F.unfold(inp, 3)[0]
inp_unf.shape
# Out:
# torch.Size([9, 676])

# %%
w = left_edge.view(-1)
w.shape
# Out:
# torch.Size([9])

# %%
out_unf = w@inp_unf
out_unf.shape
# Out:
# torch.Size([676])

# %%
out = out_unf.view(26, 26)
out.shape
# Out:
# torch.Size([26, 26])

# %%
plt.imshow(out);

# %%
# %timeit -n 1 torch.tensor([[apply_kernel(row, col, left_edge) for col in rng] for row in rng])
# Out:
# 7.85 ms ± 1.02 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit -n 100 (w@F.unfold(inp, (3, 3))).view(26, 26)
# Out:
# 115 µs ± 52.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n 100 F.conv2d(inp, left_edge[None,None])
# Out:
# 65.7 µs ± 34.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
diag1_edge = torch.tensor([
    [0, -1, 1],
    [-1, 1, 0],
    [1, 0, 0.],
])
plt.imshow(diag1_edge);

# %%
diag2_edge = torch.tensor([
    [1, -1, 0],
    [0, 1, -1],
    [0, 0, 1.],
])
plt.imshow(diag2_edge);

# %%
xb = x_imgs[:16][:,None]
xb.shape
# Out:
# torch.Size([16, 1, 28, 28])

# %%
edge_kernels = torch.stack([left_edge, top_edges, diag1_edge, diag2_edge])[:,None]

# %%
batch_features = F.conv2d(xb, edge_kernels)
batch_features.shape
# Out:
# torch.Size([16, 4, 26, 26])

# %%
o = batch_features[0]
o.shape
# Out:
# torch.Size([4, 26, 26])

# %%
_, axs = plt.subplots(1, 4, figsize=(15, 3))
for im, ax in zip(o, axs.flat):
    ax.imshow(im);
    ax.axis('off');

# %% [markdown]
# #### creating cnn

# %%
n, m = x_train.shape
c = y_train.max() + 1
nh = 50

# %%
broken_cnn = nn.Sequential(
    nn.Conv2d(1, 30, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.Conv2d(30, 10, kernel_size=3, padding=1)
)

# %%
broken_cnn(xb).shape
# Out:
# torch.Size([16, 10, 28, 28])

# %%
#|export

def conv(ni, nf, stride=2, kernel_size=3, act=True):
    res = nn.Conv2d(ni, nf, stride=stride, kernel_size=kernel_size, padding=kernel_size//2)
    if act:
        res = nn.Sequential(res, nn.ReLU())
    return res

# %%
simple_cnn = nn.Sequential(
    conv(1, 4), # 14x14
    conv(4, 8), # 7x7
    conv(8, 16), # 4x4
    conv(16, 16), # 2x2,
    conv(16, 10, act=False), # 1x1
    nn.Flatten()
)

# %%
simple_cnn(xb).shape
# Out:
# torch.Size([16, 10])

# %%
x_imgs = x_train.view(-1, 1, 28, 28)
xv_imgs = x_valid.view(-1, 1, 28, 28)
train_ds, valid_ds = Dataset(x_imgs, y_train), Dataset(xv_imgs, y_valid)
x_imgs.shape, xv_imgs.shape
# Out:
# (torch.Size([50000, 1, 28, 28]), torch.Size([10000, 1, 28, 28]))

# %%
#|export

def_device = 'cuda' if torch.cuda.is_available() else 'cpu'

def to_device(x, device=def_device):
    if isinstance(x, torch.Tensor):
        return x.to(device)
    elif isinstance(x, Mapping):
        return {k:v.to(device) for k,v in x.items()}
    return type(x)(to_device(o) for o in x)

def collate_device(b):
    return to_device(default_collate(b))

# %%
from torch import optim

bs = 256
lr = 0.4
train_dl, valid_dl = get_dls(train_ds, valid_ds, bs, collate_fn=collate_device)
opt = optim.SGD(simple_cnn.parameters(), lr=lr)

# %%
loss, acc = fit(5, simple_cnn.to(def_device), F.cross_entropy, opt, train_dl, valid_dl)
# Out:
# 0 2.299930730056763 0.12259999990463256
# 1 0.4197880989551544 0.8690999996185302
# 2 0.20536220552921294 0.9385000001907349
# 3 0.12436030631065369 0.9621000007629394
# 4 0.12824774191379548 0.9603999994277954

# %%
opt = optim.SGD(simple_cnn.parameters(), lr=lr/4)
loss, acc = fit(5, simple_cnn.to(def_device), F.cross_entropy, opt, train_dl, valid_dl)
# Out:
# 0 0.09077674753665924 0.9732999994277954
# 1 0.0849522204875946 0.9743999994277954
# 2 0.09227871530055999 0.9727000007629395
# 3 0.07988464529514312 0.9751999995231628
# 4 0.08527339699268341 0.9745999994277954

# %%
#|hide
import nbdev; nbdev.nbdev_export();
