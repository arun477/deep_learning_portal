# %% [markdown]
# https://huggingface.co/learn/audio-course/en/chapter2/tts_pipeline (ref)

# %%
# !pip install datasets

# %%
from transformers import pipeline
import IPython as ipy

# %%
pipe = pipeline("text-to-speech", model='suno/bark-small', device=0)

# %%
text = 'Ladybugs have had important roles in culture and religion, being associated with luck, love, fertility and prophecy'

# %%
preds = pipe(text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.

# %%
ipy.display.Audio(preds['audio'], rate=preds['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fr_text = "Contrairement à une idée répandue, le nombre de points sur les élytres d'une coccinelle ne correspond pas à son âge, ni en nombre d'années, ni en nombre de mois. "
preds = pipe(fr_text)
ipy.display.Audio(preds['audio'], rate=preds['sampling_rate'])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
song = "♪ In the jungle, the mighty jungle, the ladybug was seen. ♪ "
preds = pipe(song)
ipy.display.Audio(preds['audio'], rate=preds['sampling_rate'])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
music_pipe = pipeline('text-to-audio', model='facebook/musicgen-small', device=0)

# %%
text = "90s rock song with electric guitar and heavy drums"
text = "90s indian love song"

# %%
forward_params = {"max_new_tokens": 512}
preds = music_pipe(text, forward_params=forward_params)

# %%
ipy.display.Audio(preds['audio'][0], rate=preds['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
